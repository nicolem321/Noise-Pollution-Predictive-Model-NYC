# %%
import pandas as pd
import numpy as np
import pickle 
import time

# %%
total_file_name = "total_noise_complaints.pickle"
# people_file_name = "total_noise_complaints.pickle"
# traffic_file_name = "total_noise_complaints.pickle"

complaints = pickle.load(open(total_file_name, "rb"))

# %%
print(complaints.keys())
# Key = unique identifier
# Descriptor = Complaint type
# Region = community board
# Out:
# dict_keys(['Key', 'Descriptor', 'Region'])
