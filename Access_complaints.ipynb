# %%
import pandas as pd
import numpy as np
import pickle 
import time

# %%
file_name = "noise_complaints.pickle"
complaints = pickle.load(open(file_name, "rb"))
print(complaints.keys())
# Total, People, Traffic are all complaints
# region_names are the community board names
# region_areas are the area in sq miles of the community boards (same ordering as region_names)
# region_densities are the population densities in persons/sq mile of the community boards (same ordering as region_names)
# Out:
# dict_keys(['Total', 'People', 'Traffic', 'region_areas', 'region_densities', 'region_names'])

# %%
print(complaints['Total'].keys())
# ordering of each array is the same 
# Key = unique identifier
# Descriptor = Complaint type
# Region = community board
# Out:
# dict_keys(['Key', 'Descriptor', 'Region'])

# %%
print(complaints['Total']['Descriptor'][0:5])
# Out:
# ['Noise: Construction Before/After Hours (NM1)' 'Car/Truck Horn'
#  'Loud Music/Party' 'Loud Music/Party' 'Banging/Pounding']

# %%
print(complaints['region_names'])
# Out:
# ['01 STATEN ISLAND' '02 STATEN ISLAND' '03 STATEN ISLAND' '01 BRONX'
#  '02 BRONX' '03 BRONX' '04 BRONX' '05 BRONX' '06 BRONX' '07 BRONX'
#  '08 BRONX' '09 BRONX' '10 BRONX' '11 BRONX' '12 BRONX' '01 BROOKLYN'
#  '02 BROOKLYN' '03 BROOKLYN' '04 BROOKLYN' '05 BROOKLYN' '06 BROOKLYN'
#  '07 BROOKLYN' '08 BROOKLYN' '09 BROOKLYN' '10 BROOKLYN' '11 BROOKLYN'
#  '12 BROOKLYN' '13 BROOKLYN' '14 BROOKLYN' '15 BROOKLYN' '16 BROOKLYN'
#  '17 BROOKLYN' '18 BROOKLYN' '01 MANHATTAN' '02 MANHATTAN' '03 MANHATTAN'
#  '04 MANHATTAN' '05 MANHATTAN' '06 MANHATTAN' '07 MANHATTAN'
#  '08 MANHATTAN' '09 MANHATTAN' '10 MANHATTAN' '11 MANHATTAN'
#  '12 MANHATTAN' '01 QUEENS' '02 QUEENS' '03 QUEENS' '04 QUEENS'
#  '05 QUEENS' '06 QUEENS' '07 QUEENS' '08 QUEENS' '09 QUEENS' '10 QUEENS'
#  '11 QUEENS' '12 QUEENS' '13 QUEENS' '14 QUEENS']
